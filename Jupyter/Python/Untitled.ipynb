# %%
data = r"C:\Users\dutta\OneDrive\Documents\archive\\" + "s02.csv"

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(data, header=None)
df.columns=['Fp1', 'Fp2', 'F3', 'F4', 'F7', 'F8', 'T3', 'T4', 'C3', 'C4', 'T5', 'T6', 'P3', 'P4', 'O1', 'O2', 'Fz', 'Cz', 'Pz']
df["time"] = np.arange(1,31001)/500
df
# Out:
#             Fp1       Fp2         F3        F4        F7         F8  \
# 0      3.525800  0.714550   7.212700  4.161200  3.906000   1.557100
# 1      2.577400  1.416000   8.348100  5.062500  2.714600   4.660600
# 2      0.958410  1.898900   9.856400  5.894700  1.937200   7.904600
# 3     -0.975840  2.045800  11.526000  6.551700  1.913700  10.842000
# 4     -2.584100  1.845700  13.040000  6.996800  2.806300  13.297000
# ...         ...       ...        ...       ...       ...        ...
# 30995 -0.000702  0.000252   0.000048  0.000438  0.000205   0.000125
# 30996 -0.000702  0.000252   0.000048  0.000438  0.000205   0.000125
# 30997 -0.000702  0.000252   0.000048  0.000438  0.000205   0.000125
# 30998 -0.000702  0.000252   0.000048  0.000438  0.000205   0.000125
# 30999 -0.000702  0.000252   0.000048  0.000438  0.000205   0.000125
#
#               T3         T4         C3        C4        T5        T6  \
# 0       9.145700   0.997290  12.283000  6.173900  1.756000 -2.956500
# ...

# %%
df["Fp1"].to_numpy()
# Out:
# array([1.3990e+01, 1.2877e+01, 1.1885e+01, ..., 8.5942e-04, 8.5942e-04,
#        8.5942e-04])

# %%
sns.lineplot(x="time",y="F3",data = df.iloc[:500:,:])
# Out:
# <Axes: xlabel='time', ylabel='F3'>
